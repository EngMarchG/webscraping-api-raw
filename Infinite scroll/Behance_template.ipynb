# %%
import pandas as pd

# %%
import requests

headers = {
    'authority': 'www.behance.net',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Microsoft Edge";v="98"',
    'x-newrelic-id': 'VgUFVldbGwsFU1BRDwUBVw==',
    'x-bcp': 'e53da041-f066-4ae8-98b6-1838c6513568',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.80 Safari/537.36 Edg/98.0.1108.43',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search?tracking_source=typeahead_search_direct&search=architecture',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'gk_suid=61183442; gki=%7B%22feature_stock_rail%22%3Afalse%7D; bcp=e53da041-f066-4ae8-98b6-1838c6513568; ilo0=true; AMCVS_9E1005A551ED61CA0A490D45%40AdobeOrg=1; gpv=behance.net:search:projects; s_cc=true; feds_privacy_consent={"hasUserProvidedConsent":true,"userHasCustomConsent":false}; s_ppv=[%22www.behance.net/%22%2C19%2C0%2C999%2C150%2C999%2C1920%2C1080%2C1%2C%22L%22]; OptanonConsent=isIABGlobal=false&datestamp=Sun+Feb+06+2022+10%3A39%3A35+GMT%2B0200+(Eastern+European+Standard+Time)&version=6.9.0&hosts=&consentId=69df0d10-0d4c-451a-b9d1-56692b750ef2&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1&AwaitingReconsent=false; AMCV_9E1005A551ED61CA0A490D45%40AdobeOrg=870038026%7CMCMID%7C13600351303348711877397982647087139290%7CMCAID%7CNONE%7CMCOPTOUT-1644143977s%7CNONE%7CvVersion%7C5.0.0',
}

params = (
    ('content', 'projects'),
    ('search', 'architecture'),
    ('ordinal', '0'),
)

response = requests.get('https://www.behance.net/search', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://www.behance.net/search?content=projects&search=architecture&ordinal=48', headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
results_behance = response.json()

# %%
results_behance.keys()
# Out:
# dict_keys(['search', 'creativeFields', 'tools', 'schools'])

# %%
results_behance["search"]
result_items = results_behance["search"]["content"]["projects"]
result_items
# Out:
# [{'id': 130838231,
#   'name': 'Real Estate Platform - UI/UX Concept',
#   'published_on': 1636382159,
#   'created_on': 1636377677,
#   'modified_on': 1643734708,
#   'url': 'https://www.behance.net/gallery/130838231/Real-Estate-Platform-UIUX-Concept',
#   'slug': 'Real-Estate-Platform-UIUX-Concept',
#   'privacy': 'public',
#   'fields': ['Web Design', 'UI/UX', 'Interaction Design'],
#   'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/3fb70f130838231.Y3JvcCw4MDgsNjMyLDAsMA.png',
#    '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/3fb70f130838231.Y3JvcCw4MDgsNjMyLDAsMA.png',
#    '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/3fb70f130838231.Y3JvcCw4MDgsNjMyLDAsMA.png',
#    '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/3fb70f130838231.Y3JvcCw4MDgsNjMyLDAsMA.png',
#    '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/3fb70f130838231.Y3JvcCw4MDgsNjMyLDAsMA.png',
# ...

# %%
len(result_items)
# Out:
# 48

# %%
#Testing out the output of variables SKIP if not wanted
result_items[0]["name"]
result_items[0]["owners"][0]["first_name"]
result_items[0]["owners"][0]["last_name"]
result_items[0]["owners"][0]["username"]
result_items[0]["owners"][0]["country"]
result_items[0]["owners"][0]["url"]
#result_items[0]["stats"]["followers"]
result_items[0]["stats"]["appreciations"]
result_items[0]["stats"]["views"]
result_items[0]["stats"]["comments"]

print(result_items[0]["name"])
print(result_items[0]["owners"][0]["first_name"])
print(result_items[0]["owners"][0]["last_name"])
print(result_items[0]["owners"][0]["username"])
print(result_items[0]["owners"][0]["country"])
print(result_items[0]["owners"][0]["url"])
print(result_items[0]["owners"][0]["stats"]["followers"])
print(result_items[0]["owners"][0]["stats"]["appreciations"])
print(result_items[0]["owners"][0]["stats"]["views"])
print(result_items[0]["owners"][0]["stats"]["comments"])
# Out:
# Real Estate Platform - UI/UX Concept
# Pavlo Savchenko |
# LINKUP STUDIO
# pavelllsav3ccf
# Ukraine
# https://www.behance.net/pavelllsav3ccf
# 666
# 21832
# 212852
# 7

# %%
name = []
first_name = []
last_name = []
username = []
country = []
followers = []
appreciations = []
views = []
comments = []
url = []

for ele in range(len(result_items)):
    name.append(result_items[ele]["name"])
    
    first_name.append(result_items[ele]["owners"][0]["first_name"])
    
    last_name.append(result_items[ele]["owners"][0]["last_name"])
    
    username.append(result_items[ele]["owners"][0]["username"])
    
    country.append(result_items[ele]["owners"][0]["country"])
    
    followers.append(result_items[ele]["owners"][0]["stats"]["followers"])
    
    appreciations.append(result_items[ele]["owners"][0]["stats"]["appreciations"])
    
    views.append(result_items[ele]["owners"][0]["stats"]["views"])
    
    comments.append(result_items[ele]["owners"][0]["stats"]["comments"])
    
    url.append(result_items[ele]["owners"][0]["url"])

# %%
df = pd.DataFrame({"name": name, "first_name": first_name, "last_name": last_name, 
                   "username": username, "country": country, "followers": followers, 
                   "appreciations": appreciations, "views": views, "comments": comments, "url": url})

# %%
df
# Out:
#                                                  name         first_name  \
# 0                Real Estate Platform - UI/UX Concept  Pavlo Savchenko |
# 1                                      Sum+ Archtects             Mateus
# 2                                     Architecture #2              Maria
# 3                                        Nice-Cordoba                  .
# 4                   HKU Architecture Degree Show 2020            Anthony
# 5                                              INOVIL          Alexandre
# 6                                                 OOP             Futura
# 7                                Self Isolating Cabin            Clément
# 8                                 Japanese house tour              Jenny
# 9                                          flow house            Ricardo
# 10                                      Raimer Bureau               Yana
# 11                                  AS House Interior               Koma
# ...

# %%
df.to_excel("Behance_stats.xlsx", index = False)

# %%
import requests

headers = {
    'authority': 'www.behance.net',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Microsoft Edge";v="98"',
    'x-newrelic-id': 'VgUFVldbGwsFU1BRDwUBVw==',
    'x-bcp': 'e53da041-f066-4ae8-98b6-1838c6513568',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.80 Safari/537.36 Edg/98.0.1108.43',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search?tracking_source=typeahead_search_direct&search=architecture',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'gk_suid=61183442; gki=%7B%22feature_stock_rail%22%3Afalse%7D; bcp=e53da041-f066-4ae8-98b6-1838c6513568; ilo0=true; AMCVS_9E1005A551ED61CA0A490D45%40AdobeOrg=1; gpv=behance.net:search:projects; s_cc=true; feds_privacy_consent={"hasUserProvidedConsent":true,"userHasCustomConsent":false}; s_ppv=[%22www.behance.net/%22%2C19%2C0%2C999%2C150%2C999%2C1920%2C1080%2C1%2C%22L%22]; OptanonConsent=isIABGlobal=false&datestamp=Sun+Feb+06+2022+10%3A39%3A35+GMT%2B0200+(Eastern+European+Standard+Time)&version=6.9.0&hosts=&consentId=69df0d10-0d4c-451a-b9d1-56692b750ef2&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1&AwaitingReconsent=false; AMCV_9E1005A551ED61CA0A490D45%40AdobeOrg=870038026%7CMCMID%7C13600351303348711877397982647087139290%7CMCAID%7CNONE%7CMCOPTOUT-1644143977s%7CNONE%7CvVersion%7C5.0.0',
}

CONST = 48
name = []
first_name = []
last_name = []
username = []
country = []
followers = []
appreciations = []
views = []
comments = []
url = []

for i in range(10):
    #page request up to 48 items
    page = i*CONST
    
    params = (
        ('content', 'projects'),
        ('search', 'architecture'),
        ('ordinal', str(page)),
    )

    response = requests.get('https://www.behance.net/search', headers=headers, params=params)
    
    results_behance = response.json()
    result_items = results_behance["search"]["content"]["projects"]
    
    #appending all page results in lists
    for ele in range(len(result_items)):
        name.append(result_items[ele]["name"])

        first_name.append(result_items[ele]["owners"][0]["first_name"])

        last_name.append(result_items[ele]["owners"][0]["last_name"])

        username.append(result_items[ele]["owners"][0]["username"])

        country.append(result_items[ele]["owners"][0]["country"])

        followers.append(result_items[ele]["owners"][0]["stats"]["followers"])

        appreciations.append(result_items[ele]["owners"][0]["stats"]["appreciations"])

        views.append(result_items[ele]["owners"][0]["stats"]["views"])

        comments.append(result_items[ele]["owners"][0]["stats"]["comments"])

        url.append(result_items[ele]["owners"][0]["url"])

#saving lists to a data frame
df = pd.DataFrame({"name": name, "first_name": first_name, "last_name": last_name, 
                   "username": username, "country": country, "followers": followers, 
                   "appreciations": appreciations, "views": views, "comments": comments, "url": url})

df.to_excel("Behance_stats.xlsx", index = False)
